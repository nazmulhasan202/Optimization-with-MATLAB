# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from os.path import join  

# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "Optimization-with-MATLAB" 
# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/gdrive/My Drive/Git' 
# replace with your Github username 
GIT_USERNAME = "nazmulhasan202" 
# definitely replace with your
#GIT_TOKEN = "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"  
#GIT_TOKEN = "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"
#GIT_TOKEN = "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"
GIT_TOKEN = "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"

PROJECT_PATH = join(MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/gdrive/My Drive/Git
# GIT_PATH:  https://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@github.com/nazmulhasan202/Optimization-with-MATLAB.git

# %%
# %cd /content/gdrive/MyDrive/Git
# Out:
# /content/gdrive/MyDrive/Git

# %%
# %cd {GIT_REPOSITORY}
# Out:
# /content/gdrive/MyDrive/Git/Optimization-with-MATLAB

# %%
# !ls -a
# Out:
# Genetic-Algorithm-using-Optimization-Tool-App
# Genetic-Algorithm-with-Sample-Example-Problem
# .git
# Github_Commit_Optimization-with-MATLAB.ipynb
# Maximization-Problem
# Minimization-Problem
# README.md
# Solving-a-composite-all-in-one-problem
# Weighted-Sum-Method

# %%
# !git status
# Out:
# On branch main
# Your branch and 'origin/main' have diverged,
# and have 1 and 2 different commits each, respectively.
#   (use "git pull" to merge the remote branch into yours)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	Genetic-Algorithm-using-Optimization-Tool-App/
# 	Genetic-Algorithm-with-Sample-Example-Problem/
# 	Github_Commit_Optimization-with-MATLAB.ipynb
# 	Maximization-Problem/
# 	Minimization-Problem/
# 	Solving-a-composite-all-in-one-problem/
# 	Weighted-Sum-Method/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .

# %% [markdown]
# # Change the commit message accordingly

# %%
# !git config --global user.email "nh202@email.arizona.edu"
# !git config --global user.name "nazmulhasan202"

# %%
# !git commit -a -m "Uploaded folders"
# Out:
# [main 5e35d9f] Uploaded folders
#  25 files changed, 182 insertions(+)
#  create mode 100644 Genetic-Algorithm-using-Optimization-Tool-App/README.md
#  create mode 100644 Genetic-Algorithm-using-Optimization-Tool-App/cons_ga_app.m
#  create mode 100644 Genetic-Algorithm-using-Optimization-Tool-App/obj_ga_app.m
#  create mode 100644 Genetic-Algorithm-with-Sample-Example-Problem/README.md
#  create mode 100644 Genetic-Algorithm-with-Sample-Example-Problem/moo_calling.m
#  create mode 100644 Genetic-Algorithm-with-Sample-Example-Problem/moo_const.m
#  create mode 100644 Genetic-Algorithm-with-Sample-Example-Problem/moo_objective_functions.m
#  create mode 100644 Github_Commit_Optimization-with-MATLAB.ipynb
#  create mode 100644 Maximization-Problem/README.md
#  create mode 100644 Maximization-Problem/conditions_max_area.m
#  create mode 100644 Maximization-Problem/fun_call_max.m
#  create mode 100644 Maximization-Problem/fun_max_area.m
#  create mode 100644 Minimization-Problem/README.md
#  create mode 100644 Minimization-Problem/aboltabol.m
#  create mode 100644 Minimization-Problem/conditions.m
#  create mode 100644 Minimization-Problem/fun_call.m
#  create mode 100644 Solving-a-composite-all-in-one-problem/Github_Clone_MATLB-codes-for-solving-a-composite-all-in-one-problem.ipynb
#  create mode 100644 Solving-a-composite-all-in-one-problem/README.md
#  create mode 100644 Solving-a-composite-all-in-one-problem/constraints.m
#  create mode 100644 Solving-a-composite-all-in-one-problem/fun_calling_template.m
#  create mode 100644 Solving-a-composite-all-in-one-problem/obj_func.m
#  create mode 100644 Weighted-Sum-Method/README.md
#  create mode 100644 Weighted-Sum-Method/cons_wsm.m
#  create mode 100644 Weighted-Sum-Method/obj_wsm.m
#  create mode 100644 Weighted-Sum-Method/wsm.m

# %% [markdown]
# # Push Opertation

# %%
# !git remote set-url origin https://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@github.com/nazmulhasan202/LPBF_Defects_Ontology.git

# %%
# !git push
# Out:
# Counting objects: 33, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (33/33), done.
# Writing objects: 100% (33/33), 9.49 KiB | 323.00 KiB/s, done.
# Total 33 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), done.
# To https://github.com/nazmulhasan202/Optimization-with-MATLAB.git
#    7884a23..5e35d9f  main -> main

# %% [markdown]
# # Pull Opertation

# %%
# !git pull
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address
